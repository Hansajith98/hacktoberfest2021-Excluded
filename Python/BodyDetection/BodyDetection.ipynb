# %%
#Pose estimation

# %%
#importing libraries
import cv2
import mediapipe as mp

# %%
#capturing video
cap=cv2.VideoCapture(0)

#this will help us detect the pose and draw the reference points
mpPose=mp.solutions.pose
pose=mpPose.Pose()
mpDraw=mp.solutions.drawing_utils

#variables required to print frame rate
previous_time=0
current_time=0

#video
while True:
    success, img=cap.read()
    
    #converting image to rgb
    img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    
    results=pose.process(img_rgb)
    
    if results.pose_landmarks:
        mpDraw.draw_landmarks(img, results.pose_landmarks, mpPose.POSE_CONNECTIONS)
    
    #calculating the frame rate
    current_time=time.time()
    frame_rate=1/(current_time-previous_time)
    previous_time=current_time
    
    #displaying the results
    cv2.putText(img, str(int(frame_rate)), (20, 40), cv2.FONT_HERSHEY_PLAIN, 3, (0, 0, 255), 3)
    cv2.imshow("camera", img)
    if cv2.waitKey(1) & 0xFF==ord('q'):
        cap.release()
        cv2.destroyAllWindows()
        break
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-0d4896aaa72f> in <module>
#      14     img_rgb=cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
#      15
# ---> 16     results=pose.process(img_rgb)
#      17
#      18     if results.pose_landmarks:
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\mediapipe\python\solutions\pose.py in process(self, image)
#     203     """
#     204
# --> 205     results = super().process(input_data={'image': image})
#     206     if results.pose_landmarks:
#     207       for landmark in results.pose_landmarks.landmark:
#
# ~\anaconda3\envs\tensorflow\lib\site-packages\mediapipe\python\solution_base.py in process(self, input_data)
#     316             f'type is not supported yet.')
#     317
# --> 318     self._graph.wait_until_idle()
#     319     # Create a NamedTuple object where the field names are mapping to the graph
#     320     # output stream names.
#
# KeyboardInterrupt:
